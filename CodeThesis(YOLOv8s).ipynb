# %%
# !nvidia-smi
# Out:
# Sat Jun  3 16:03:51 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.112 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CodeThesis
# Out:
# /content/drive/MyDrive/CodeThesis

# %%
# %cd /content/drive/MyDrive/CodeThesis

# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=50 imgsz=224 plots=True
# Out:
# /content/drive/MyDrive/CodeThesis
# ...
# 100% 21.5M/21.5M [00:00<00:00, 138MB/s]
# Ultralytics YOLOv8.0.112 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=runs/detect/train3/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.0.112 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/CodeThesis/valid/labels.cache... 283 images, 0 backgrounds, 0 corrupt: 100% 283/283 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:08<00:00,  2.01it/s]
#                    all        283        349      0.963      0.958      0.971      0.651
#                   hole        283         61       0.96      0.951       0.96      0.681
#                   knot        283         59      0.983       0.99      0.994      0.607
#                   slub        283         53      0.993          1      0.995      0.765
#                   snag        283         56      0.914       0.95      0.961      0.548
#                  stain        283        120      0.964        0.9      0.946      0.654
# ...
